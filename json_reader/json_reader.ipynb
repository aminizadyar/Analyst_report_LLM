# %%
import pandas as pd

# Load the JSON file into a DataFrame
df = pd.read_json('Clean_data_BARCLAYS.json')

# Display the DataFrame
print(df)
# Out:
#          D:\ThomsonOne TXT/BARCLAYS\Report_BARCLAYS_2014-09-26_Page_1_Doc_0.txt
# Ticker                                                15 OP                      \
# Rating                                                 None
# Content   Toyota Boshoku\r\nShares seem to factor in exc...
# Analysis  Shares seem to factor in excessive expectation...
# Emails    [takafumi.miura@barclays.com, tatsuo.yoshida@b...
# Phones      [+81 3 4530 2924, +813 4530 2931, 212-526-1072]
#
#          D:\ThomsonOne TXT/BARCLAYS\Report_BARCLAYS_2014-09-26_Page_1_Doc_1.txt
# Ticker                                               2784.T                      \
# Rating                                                    1
# Content   Alfresa Holdings Corp.\r\nChange of target pri...
# Analysis  We change our target price to JPY1,950 to refl...
# Emails    [atsushi.seki@barclays.com, xiaoyi.wang@barcla...
# Phones     [+81 3 4530 2934, +81 3 4530 2979, 212-526-1072]
#
# ...

# %%
text_1 = r"D:\ThomsonOne TXT/BARCLAYS" 

text_2 = r"\Report_BARCLAYS_2018-10-22_Page_1_Doc_1.txt"
file_name = text_1 + text_2

# %%
df.head(5)
# Out:
#          D:\ThomsonOne TXT/BARCLAYS\Report_BARCLAYS_2014-09-26_Page_1_Doc_0.txt
# Ticker                                                15 OP                      \
# Rating                                                 None
# Content   Toyota Boshoku\r\nShares seem to factor in exc...
# Analysis  Shares seem to factor in excessive expectation...
# Emails    [takafumi.miura@barclays.com, tatsuo.yoshida@b...
#
#          D:\ThomsonOne TXT/BARCLAYS\Report_BARCLAYS_2014-09-26_Page_1_Doc_1.txt
# Ticker                                               2784.T                      \
# Rating                                                    1
# Content   Alfresa Holdings Corp.\r\nChange of target pri...
# Analysis  We change our target price to JPY1,950 to refl...
# Emails    [atsushi.seki@barclays.com, xiaoyi.wang@barcla...
#
#          D:\ThomsonOne TXT/BARCLAYS\Report_BARCLAYS_2014-09-26_Page_1_Doc_10.txt
# ...

# %%
df.columns
# Out:
# Index(['D:\ThomsonOne TXT/BARCLAYS\Report_BARCLAYS_2014-09-26_Page_1_Doc_0.txt',
#        'D:\ThomsonOne TXT/BARCLAYS\Report_BARCLAYS_2014-09-26_Page_1_Doc_1.txt',
#        'D:\ThomsonOne TXT/BARCLAYS\Report_BARCLAYS_2014-09-26_Page_1_Doc_10.txt',
#        'D:\ThomsonOne TXT/BARCLAYS\Report_BARCLAYS_2014-09-26_Page_1_Doc_11.txt',
#        'D:\ThomsonOne TXT/BARCLAYS\Report_BARCLAYS_2014-09-26_Page_1_Doc_12.txt',
#        'D:\ThomsonOne TXT/BARCLAYS\Report_BARCLAYS_2014-09-26_Page_1_Doc_13.txt',
#        'D:\ThomsonOne TXT/BARCLAYS\Report_BARCLAYS_2014-09-26_Page_1_Doc_14.txt',
#        'D:\ThomsonOne TXT/BARCLAYS\Report_BARCLAYS_2014-09-26_Page_1_Doc_15.txt',
#        'D:\ThomsonOne TXT/BARCLAYS\Report_BARCLAYS_2014-09-26_Page_1_Doc_16.txt',
#        'D:\ThomsonOne TXT/BARCLAYS\Report_BARCLAYS_2014-09-26_Page_1_Doc_17.txt',
#        ...
#        'D:\ThomsonOne TXT/BARCLAYS\Report_BARCLAYS_2018-12-21_Page_1_Doc_9.txt',
# ...

# %%
#filtered_df = df[df['File'].str.contains('Report_JPMORGAN_2009-09-25_Page_1_Doc_37.txt')]
filtered_df = df[file_name]

# %%
filtered_df
# Out:
# Ticker                                           BEGINNING ON
# Rating                                                      1
# Content     CORE\r\n\r\nIQVIA\r\nSeeing Positive Leading I...
# Analysis    Despite the muted stock reaction for IQVIA fol...
# Emails      [jack.meehan@barclays.com, mitchell.petersen@b...
# Phones      [+1 212 526 3909, +1 212 526 3367, +1 212 526 ...
# Name: D:\ThomsonOne TXT/BARCLAYS\Report_BARCLAYS_2018-10-22_Page_1_Doc_1.txt, dtype: object

# %%
#str_extracted = filtered_df["Analysis"].item()
str_extracted = filtered_df["Analysis"]

# %%
len(str_extracted)
# Out:
# 26646

# %%
text_file = open("Output.txt", "w")

text_file.write(str_extracted)

text_file.close()
